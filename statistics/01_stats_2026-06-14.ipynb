# %% [markdown]
# # Statistics - 14th June 2026
# Source - Statistics: A step-by-step introduction
# By Brian Greco on Udemy
#
# **Today's goal: finish chapters 13 - 16**
#
# ## What I learned
# - Unions of events
# - Venn diagrams
# - Calculations of intersections and conditional probability
# - Disjointed events are automatically dependent
# - Disjointed events are **not** independent
# - Probability of one independent event does not affect the probabilty of another independent event
# - Occurance of one disjointed event makes the probability of the other disjointed event 0
#
# ## Things that confused me
# - How does dependent probability *not* directly mean causality?
# - I know it in theory, the classical ice cream sales and shark attacks is easy conceptually. But how do we statistically test for causality?
#
# ## Challenges
# - Some of these concepts do not feel intuitive to me at all
#
# ## Possible use cases
# - Probability of a certain amount of coin flips?
# - But what about real world applications?
#
# **Next step: Finish Quiz 5 and continue to the next chapters. Finish Section 2.**
